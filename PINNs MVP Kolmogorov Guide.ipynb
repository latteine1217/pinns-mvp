# %% [markdown]
# ---
#
# ## Part 0: Google Colab 初始化
#
# **⚠️ 重要**：本 Notebook 專為 **Google Colab (T4/A100 GPU)** 設計。

# %%
# 0.1 檢測環境
try:
    import google.colab
    IN_COLAB = True
    print("✅ Google Colab 環境")
except ImportError:
    IN_COLAB = False
    print("⚠️  本地環境，請使用: python scripts/train/train.py --cfg <config.yml>")

# 0.2 掛載 Google Drive 並設定模組路徑
if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')

    import os
    import sys
    PROJECT_PATH = '/content/drive/MyDrive/pinns-sparse-flow'

    if os.path.exists(PROJECT_PATH):
        os.chdir(PROJECT_PATH)
        print(f"✅ 專案目錄: {os.getcwd()}")

        # 將專案根目錄加入 Python 模組搜尋路徑
        if PROJECT_PATH not in sys.path:
            sys.path.insert(0, PROJECT_PATH)
            print(f"✅ 已加入模組路徑: {PROJECT_PATH}")

    else:
        raise FileNotFoundError(f"專案不存在: {PROJECT_PATH}\n請上傳專案至 Google Drive")
else:
    import os
    import sys
    project_root = os.getcwd()
    if project_root not in sys.path:
        sys.path.insert(0, project_root)
        print(f"✅ 本地環境，已加入模組路徑: {project_root}")

# !export PYTHONPATH=/content/drive/MyDrive/pinns-sparse-flow:$PYTHONPATH
import wandb
wandb.login(key="daf43f72d9f4f636dc69479c446ace76a4a3eb92")
# Out:
# ✅ Google Colab 環境
# Mounted at /content/drive
# ✅ 專案目錄: /content/drive/MyDrive/pinns-sparse-flow
# ✅ 已加入模組路徑: /content/drive/MyDrive/pinns-sparse-flow
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: felix-tc-tw (felix-tc-tw-national-tsinghua-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# !bash scripts/experiments/run_s2_k_scan_colab.sh 30
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# 2026-01-06 22:42:23,071 - pinnx.train.checkpointing - INFO - ============================================================
# 2026-01-06 22:42:23,072 - pinnx.train.checkpointing - INFO - 📊 物理診斷報告
# 2026-01-06 22:42:23,072 - pinnx.train.checkpointing - INFO - ============================================================
# 2026-01-06 22:42:23,073 - pinnx.train.checkpointing - INFO - 質量守恆誤差: 2.667148e+01 (閾值: 1.000000e-03) [✗]
# 2026-01-06 22:42:23,074 - pinnx.train.checkpointing - INFO - 動量守恆誤差: 2.252262e+01 (閾值: 1.000000e-02) [✗]
# 2026-01-06 22:42:23,127 - pinnx.train.checkpointing - INFO - 邊界條件誤差: 9.689701e-01 (閾值: 1.000000e-03) [✗]
# 2026-01-06 22:42:23,128 - pinnx.train.checkpointing - INFO - ℹ️  物理診斷：約束未滿足（訓練初期正常）
# 2026-01-06 22:42:23,128 - pinnx.train.checkpointing - INFO - ============================================================
# ...

# %%
# 執行訓練
# !python scripts/train/train.py --cfg configs/experiments//S1_sensor_strategy/s1_qr_K100_2d_re50.yml

# 檢查點保存至: checkpoints/kolmogorov_re50_kf4_K100_rans_prior/
# 結果保存至: results/kolmogorov_re50_kf4_K100_rans_prior/
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# 串流輸出內容已截斷至最後 5000 行。
# 2026-01-05 13:44:47,801 - root - INFO - ✅ Checkpoint saved: checkpoints/experiments/S1_qr_K100/checkpoint_epoch1200_loss0.000000_20260105_134447.pt
# 2026-01-05 13:44:47,827 - root - INFO - ⭐ 最佳模型已保存: checkpoints/experiments/S1_qr_K100/best_model.pth
# 2026-01-05 13:44:47,830 - root - INFO - 🗑️  Removed old checkpoint: checkpoints/experiments/S1_qr_K100/checkpoint_epoch1200_loss0.000000_20260105_134447.pt
# 2026-01-05 13:44:47,831 - root - INFO - 🎯 新最佳指標: 0.253441（epoch 1200）
# 2026-01-05 13:44:48,222 - pinnx.train.checkpointing - INFO - ============================================================
# 2026-01-05 13:44:48,222 - pinnx.train.checkpointing - INFO - 📊 物理診斷報告
# ...
